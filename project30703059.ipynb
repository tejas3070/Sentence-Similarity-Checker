# %%
from nltk import word_tokenize
from nltk import sent_tokenize
from nltk.corpus import wordnet as wn
import numpy as np
from nltk.corpus import brown
import math
import nltk


CONST_PHI = 0.2
CONST_BETA = 0.45
CONST_ALPHA = 0.2
CONST_PHI = 0.2
CONST_DELTA = 0.875
CONST_ETA = 0.4
total_words = 0
word_freq_brown = {}


def proper_synset(word_one, word_two):
    pair = (None, None)
    maximum_similarity = -1
    synsets_one = wn.synsets(word_one)
    synsets_two = wn.synsets(word_two)
    print("first word :", word_one)
    print("second word", word_two)
    print(synsets_one)
    print(synsets_two)
    if (len(synsets_one) != 0 and len(synsets_two) != 0):
        for synset_one in synsets_one:
            for synset_two in synsets_two:
                similarity = wn.path_similarity(synset_one, synset_two)
                if (similarity == None):
                    sim = -2
                elif (similarity > maximum_similarity):
                    maximum_similarity = similarity
                    pair = synset_one, synset_two
    else:
        pair = (None, None)
    return pair


def length_between_words(synset_one, synset_two):
    length = 100000000
    if synset_one is None or synset_two is None:
        return 0
    elif (synset_one == synset_two):
        length = 0
    else:
        words_synet1 = set([word.name() for word in synset_one.lemmas()])
        words_synet2 = set([word.name() for word in synset_two.lemmas()])
        if (len(words_synet1) + len(words_synet2) > len(words_synet1.union(words_synet2))):
            length = 0
        else:
            length = synset_one.shortest_path_distance(synset_two)
            if (length is None):
                return 0
    return math.exp(-1 * CONST_ALPHA * length)


def depth_common_subsumer(synset_one, synset_two):
    height = 100000000
    if synset_one is None or synset_two is None:
        return 0
    elif synset_one == synset_two:
        height = max([hypernym[1] for hypernym in synset_one.hypernym_distances()])
    else:
        
        hypernym_one = {hypernym_word[0]: hypernym_word[1] for hypernym_word in synset_one.hypernym_distances()}
        hypernym_two = {hypernym_word[0]: hypernym_word[1] for hypernym_word in synset_two.hypernym_distances()}
        common_subsumer = set(hypernym_one.keys()).intersection(set(hypernym_two.keys()))
        if (len(common_subsumer) == 0):
            height = 0
        else:
            height = 0
            for cs in common_subsumer:
                val = [hypernym_word[1] for hypernym_word in cs.hypernym_distances()]
                val = max(val)
                if val > height: height = val

   
    return (math.exp(CONST_BETA * height) - math.exp(-CONST_BETA * height)) / (
                math.exp(CONST_BETA * height) + math.exp(-CONST_BETA * height))


def word_similarity(word1, word2):

    synset_wordone, synset_wordtwo = proper_synset(word1,word2) 
    return length_between_words(synset_wordone, synset_wordtwo) * depth_common_subsumer(synset_wordone, synset_wordtwo)


def I(search_word):
    global total_words
    if (total_words == 0):
        for sent in brown.sents():
            for word in sent:
                word = word.lower()
                if word not in word_freq_brown:
                    word_freq_brown[word] = 0
                word_freq_brown[word] += 1
                total_words += 1
    count = 0 if search_word not in word_freq_brown else word_freq_brown[search_word]
    ret = 1.0 - (math.log(count + 1) / math.log(total_words + 1))
    return ret


def most_similar_word(word, sentence):
    most_similarity = 0
    most_similar_word = ''
    for w in sentence:
        sim = word_similarity(w, word)
        if sim > most_similarity:
            most_similarity = sim
            most_similar_word = w
    if most_similarity <= CONST_PHI:
        most_similarity = 0
    return most_similar_word, most_similarity


def gen_sem_vec(sentence, joint_word_set):
    semantic_vector = np.zeros(len(joint_word_set))
   
    i = 0
    for joint_word in joint_word_set:
        sim_word = joint_word 
        beta_sim_measure = 1
        if (joint_word in sentence):
            pass
        else:
            sim_word, beta_sim_measure = most_similar_word(joint_word,
                                                           sentence) 
            beta_sim_measure = 0 if beta_sim_measure <= CONST_PHI else beta_sim_measure
        sim_measure = beta_sim_measure * I(joint_word) * I(sim_word)
       
        semantic_vector[i] = sim_measure
        i += 1
    return semantic_vector


def sent_sim(sent_set_one, sent_set_two, joint_word_set):

    print("Sent set one:", sent_set_one)
    print("Sent set two:", sent_set_two)
    sem_vec_one = gen_sem_vec(sent_set_one, joint_word_set)
    sem_vec_two = gen_sem_vec(sent_set_two, joint_word_set)
    print("Semantic vector 1:", sem_vec_one)
    print("Semantic vector 2:", sem_vec_two)
    return np.dot(sem_vec_one, sem_vec_two.T) / (np.linalg.norm(sem_vec_one) * np.linalg.norm(sem_vec_two))


def word_order_similarity(sentence_one, sentence_two):
    print("Sentence one :", sentence_one)
    token_one = word_tokenize(sentence_one)
    print("Sentence two : ", sentence_two)
    token_two = word_tokenize(sentence_two)
    joint_word_set = list(set(token_one).union(set(token_two)))
    r1 = np.zeros(len(joint_word_set))
    r2 = np.zeros(len(joint_word_set))
    en_joint_one = {x[1]: x[0] for x in enumerate(token_one)}
    en_joint_two = {x[1]: x[0] for x in enumerate(token_two)}
    set_token_one = set(token_one)
    set_token_two = set(token_two)
    i = 0
    j=0
    for word in joint_word_set:
        if word in set_token_one:
            r1[i] = en_joint_one[word]  
        else:
    
            sim_word, sim = most_similar_word(word, list(set_token_one))
            if sim > CONST_ETA:
                r1[i] = en_joint_one[sim_word]
            else:
                r1[i] = 0
        i += 1
    for word in joint_word_set:
        if word in set_token_two:
            r2[j] = en_joint_two[word]
        else:
            sim_word, sim = most_similar_word(word, list(set_token_two))
            if sim > CONST_ETA:
                r2[j] = en_joint_two[sim_word]
            else:
                r2[j] = 0
        j += 1
    value = 1.0 - (np.linalg.norm(r1 - r2) / np.linalg.norm(r1 + r2))
    print("Word Order Similarity is:", value)
    return 1.0 - (np.linalg.norm(r1 - r2) / np.linalg.norm(r1 + r2))


def main(sentence_one, sentence_two):
    sent_set_one = set(filter(lambda x: not (x == '.' or x == '?'), word_tokenize(sentence_one)))
    sent_set_two = set(filter(lambda x: not (x == '.' or x == '?'), word_tokenize(sentence_two)))
    joint_word_set = list(sent_set_one.union(sent_set_two))
    sentence_similarity = (CONST_DELTA * sent_sim(sent_set_one, sent_set_two, list(joint_word_set))) + (
                (1.0 - CONST_DELTA) * word_order_similarity(sentence_one, sentence_two))
    return sentence_similarity


def file_sem(f):
    contents = open(f).read().strip()
    ind_sentences = sent_tokenize(contents)
    no_of_sentences = len(ind_sentences)
    sent_sim_matr = np.zeros((no_of_sentences, no_of_sentences))
    i = 0
    print(ind_sentences)
    while (i < no_of_sentences):
        j = i
        while (j < no_of_sentences):
            sent_sim_matr[i][j] = main(ind_sentences[i], ind_sentences[j])
            sent_sim_matr[j][i] = sent_sim_matr[i][j]
            j += 1
        i += 1
    return sent_sim_matr


def intro():
    print("\nEnter a valid option:\n")
    print("1.Sentence Similarity between two files containing different sentences.")
    print("2.Sentence similarity between two sentences\n")
    option = int(input("Your choice : "))
    if option == 1:
        file_one = input("Enter the path of the file :")
        file_two = input("Enter the path of the second file")
        with open(file_one, 'r') as content_file:
            sent_one = content_file.read()
        with open(file_two, 'r') as content_file:
            sent_two = content_file.read()
            prob_sim_sent = main(sent_one, sent_two)
            print("Similarity between the sentences between the 2 file is : \n")
            print(prob_sim_sent)

    
        f_n = file_one[0:len(file_one) - 4:] + "_matrix.txt"
        output_file = open(f_n, 'w')
        output_file.write(str(prob_sim_sent))
    elif option == 2:
        sent_one = input("Enter the first sentence : ")
        sent_two = input("Enter the second sentence two :")
        prob_sim_sent = main(sent_one, sent_two)
        print(prob_sim_sent)
        print("Similarity between "+sent_one+" "+sent_two+" is : ",prob_sim_sent)
    else:
        global max_count
        if max_count < 3:
            print("Wrong Choice Try again"); max_count += 1
        else:
            print("Wrong choice time exceeded!");exit()
        intro()


if __name__ == "__main__":
    print("-------------------Sentence Similarity--------------------------")
    intro()
    print("Want to try once again? if yes press 1 or else 0")
    excited = int(input())
    while (excited == 1):
        intro()
        print("Want to try once again?")
        excited = int(input())
# Out:
# -------------------Sentence Similarity--------------------------
#
# Enter a valid option:
#
# 1.Sentence Similarity between two files containing different sentences.
# 2.Sentence similarity between two sentences
#
# Your choice : 1
# Enter the path of the file :D:\input1.txt
# Enter the path of the second fileD:\input2.txt
# Sent set one: {'lazy', 'is', 'A', 'dog.Its', 'over', 'the', 'ferocious', 'attitude', 'brown', 'fox', 'quick', 'jumps'}
# Sent set two: {'lazy', 'fox.Its', 'is', 'calm', 'A', 'nature', 'over', 'the', 'very', 'brown', 'in', 'and', 'composure', 'timid', 'dog', 'quick', 'jumps'}
# first word : lazy
# second word calm
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : is
# second word calm
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : A
# second word calm
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : dog.Its
# second word calm
# []
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : over
# second word calm
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : the
# second word calm
# []
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : ferocious
# second word calm
# [Synset('ferocious.s.01')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : attitude
# second word calm
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : brown
# second word calm
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : fox
# second word calm
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : quick
# second word calm
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : jumps
# second word calm
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# first word : lazy
# second word nature
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : is
# second word nature
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : A
# second word nature
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : dog.Its
# second word nature
# []
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : over
# second word nature
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : the
# second word nature
# []
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : ferocious
# second word nature
# [Synset('ferocious.s.01')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : attitude
# second word nature
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : brown
# second word nature
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : fox
# second word nature
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : quick
# second word nature
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : jumps
# second word nature
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# first word : lazy
# second word very
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : is
# second word very
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : A
# second word very
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : dog.Its
# second word very
# []
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : over
# second word very
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : the
# second word very
# []
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : ferocious
# second word very
# [Synset('ferocious.s.01')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : attitude
# second word very
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : brown
# second word very
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : fox
# second word very
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : quick
# second word very
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : jumps
# second word very
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# first word : lazy
# second word in
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : is
# second word in
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : A
# second word in
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : dog.Its
# second word in
# []
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : over
# second word in
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : the
# second word in
# []
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : ferocious
# second word in
# [Synset('ferocious.s.01')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : attitude
# second word in
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : brown
# second word in
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : fox
# second word in
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : quick
# second word in
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : jumps
# second word in
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# first word : lazy
# second word and
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# []
# first word : is
# second word and
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# []
# first word : A
# second word and
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# []
# first word : dog.Its
# second word and
# []
# []
# first word : over
# second word and
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# []
# first word : the
# second word and
# []
# []
# first word : ferocious
# second word and
# [Synset('ferocious.s.01')]
# []
# first word : attitude
# second word and
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# []
# first word : brown
# second word and
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# []
# first word : fox
# second word and
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# []
# first word : quick
# second word and
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# []
# first word : jumps
# second word and
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# []
# first word : lazy
# second word composure
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('composure.n.01')]
# first word : is
# second word composure
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('composure.n.01')]
# first word : A
# second word composure
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('composure.n.01')]
# first word : dog.Its
# second word composure
# []
# [Synset('composure.n.01')]
# first word : over
# second word composure
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('composure.n.01')]
# first word : the
# second word composure
# []
# [Synset('composure.n.01')]
# first word : ferocious
# second word composure
# [Synset('ferocious.s.01')]
# [Synset('composure.n.01')]
# first word : attitude
# second word composure
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# [Synset('composure.n.01')]
# first word : brown
# second word composure
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('composure.n.01')]
# first word : fox
# second word composure
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# [Synset('composure.n.01')]
# first word : quick
# second word composure
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('composure.n.01')]
# first word : jumps
# second word composure
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('composure.n.01')]
# first word : lazy
# second word fox.Its
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# []
# first word : is
# second word fox.Its
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# []
# first word : A
# second word fox.Its
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# []
# first word : dog.Its
# second word fox.Its
# []
# []
# first word : over
# second word fox.Its
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# []
# first word : the
# second word fox.Its
# []
# []
# first word : ferocious
# second word fox.Its
# [Synset('ferocious.s.01')]
# []
# first word : attitude
# second word fox.Its
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# []
# first word : brown
# second word fox.Its
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# []
# first word : fox
# second word fox.Its
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# []
# first word : quick
# second word fox.Its
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# []
# first word : jumps
# second word fox.Its
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# []
# first word : lazy
# second word timid
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : is
# second word timid
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : A
# second word timid
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : dog.Its
# second word timid
# []
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : over
# second word timid
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : the
# second word timid
# []
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : ferocious
# second word timid
# [Synset('ferocious.s.01')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : attitude
# second word timid
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : brown
# second word timid
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : fox
# second word timid
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : quick
# second word timid
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : jumps
# second word timid
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# first word : lazy
# second word dog
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : is
# second word dog
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : A
# second word dog
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : dog.Its
# second word dog
# []
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : over
# second word dog
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : the
# second word dog
# []
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : ferocious
# second word dog
# [Synset('ferocious.s.01')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : attitude
# second word dog
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : brown
# second word dog
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : fox
# second word dog
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : quick
# second word dog
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : jumps
# second word dog
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# first word : lazy
# second word fox
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : fox.Its
# second word fox
# []
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : is
# second word fox
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : calm
# second word fox
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : A
# second word fox
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : nature
# second word fox
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : over
# second word fox
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : the
# second word fox
# []
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : very
# second word fox
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : brown
# second word fox
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : in
# second word fox
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : and
# second word fox
# []
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : composure
# second word fox
# [Synset('composure.n.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : timid
# second word fox
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : dog
# second word fox
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : quick
# second word fox
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : jumps
# second word fox
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : lazy
# second word dog.Its
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# []
# first word : fox.Its
# second word dog.Its
# []
# []
# first word : is
# second word dog.Its
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# []
# first word : calm
# second word dog.Its
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# []
# first word : A
# second word dog.Its
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# []
# first word : nature
# second word dog.Its
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# []
# first word : over
# second word dog.Its
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# []
# first word : the
# second word dog.Its
# []
# []
# first word : very
# second word dog.Its
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# []
# first word : brown
# second word dog.Its
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# []
# first word : in
# second word dog.Its
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# []
# first word : and
# second word dog.Its
# []
# []
# first word : composure
# second word dog.Its
# [Synset('composure.n.01')]
# []
# first word : timid
# second word dog.Its
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# []
# first word : dog
# second word dog.Its
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# []
# first word : quick
# second word dog.Its
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# []
# first word : jumps
# second word dog.Its
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# []
# first word : lazy
# second word ferocious
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('ferocious.s.01')]
# first word : fox.Its
# second word ferocious
# []
# [Synset('ferocious.s.01')]
# first word : is
# second word ferocious
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('ferocious.s.01')]
# first word : calm
# second word ferocious
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# [Synset('ferocious.s.01')]
# first word : A
# second word ferocious
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('ferocious.s.01')]
# first word : nature
# second word ferocious
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# [Synset('ferocious.s.01')]
# first word : over
# second word ferocious
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('ferocious.s.01')]
# first word : the
# second word ferocious
# []
# [Synset('ferocious.s.01')]
# first word : very
# second word ferocious
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# [Synset('ferocious.s.01')]
# first word : brown
# second word ferocious
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('ferocious.s.01')]
# first word : in
# second word ferocious
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('ferocious.s.01')]
# first word : and
# second word ferocious
# []
# [Synset('ferocious.s.01')]
# first word : composure
# second word ferocious
# [Synset('composure.n.01')]
# [Synset('ferocious.s.01')]
# first word : timid
# second word ferocious
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# [Synset('ferocious.s.01')]
# first word : dog
# second word ferocious
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# [Synset('ferocious.s.01')]
# first word : quick
# second word ferocious
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('ferocious.s.01')]
# first word : jumps
# second word ferocious
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('ferocious.s.01')]
# first word : lazy
# second word attitude
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : fox.Its
# second word attitude
# []
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : is
# second word attitude
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : calm
# second word attitude
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : A
# second word attitude
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : nature
# second word attitude
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : over
# second word attitude
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : the
# second word attitude
# []
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : very
# second word attitude
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : brown
# second word attitude
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : in
# second word attitude
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : and
# second word attitude
# []
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : composure
# second word attitude
# [Synset('composure.n.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : timid
# second word attitude
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : dog
# second word attitude
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : quick
# second word attitude
# ...
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : the
# second word fox
# []
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : very
# second word fox
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : brown
# second word fox
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : in
# second word fox
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : and
# second word fox
# []
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : .
# second word fox
# []
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : composure
# second word fox
# [Synset('composure.n.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : timid
# second word fox
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : dog
# second word fox
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : quick
# second word fox
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : jumps
# second word fox
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('fox.n.01'), Synset('dodger.n.01'), Synset('fox.n.03'), Synset('fox.n.04'), Synset('fox.n.05'), Synset('fox.n.06'), Synset('fox.n.07'), Synset('flim-flam.v.01'), Synset('confuse.v.02'), Synset('fox.v.03')]
# first word : lazy
# second word dog.Its
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# []
# first word : fox.Its
# second word dog.Its
# []
# []
# first word : is
# second word dog.Its
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# []
# first word : calm
# second word dog.Its
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# []
# first word : A
# second word dog.Its
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# []
# first word : nature
# second word dog.Its
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# []
# first word : over
# second word dog.Its
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# []
# first word : the
# second word dog.Its
# []
# []
# first word : very
# second word dog.Its
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# []
# first word : brown
# second word dog.Its
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# []
# first word : in
# second word dog.Its
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# []
# first word : and
# second word dog.Its
# []
# []
# first word : .
# second word dog.Its
# []
# []
# first word : composure
# second word dog.Its
# [Synset('composure.n.01')]
# []
# first word : timid
# second word dog.Its
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# []
# first word : dog
# second word dog.Its
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# []
# first word : quick
# second word dog.Its
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# []
# first word : jumps
# second word dog.Its
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# []
# first word : lazy
# second word ferocious
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('ferocious.s.01')]
# first word : fox.Its
# second word ferocious
# []
# [Synset('ferocious.s.01')]
# first word : is
# second word ferocious
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('ferocious.s.01')]
# first word : calm
# second word ferocious
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# [Synset('ferocious.s.01')]
# first word : A
# second word ferocious
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('ferocious.s.01')]
# first word : nature
# second word ferocious
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# [Synset('ferocious.s.01')]
# first word : over
# second word ferocious
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('ferocious.s.01')]
# first word : the
# second word ferocious
# []
# [Synset('ferocious.s.01')]
# first word : very
# second word ferocious
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# [Synset('ferocious.s.01')]
# first word : brown
# second word ferocious
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('ferocious.s.01')]
# first word : in
# second word ferocious
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('ferocious.s.01')]
# first word : and
# second word ferocious
# []
# [Synset('ferocious.s.01')]
# first word : .
# second word ferocious
# []
# [Synset('ferocious.s.01')]
# first word : composure
# second word ferocious
# [Synset('composure.n.01')]
# [Synset('ferocious.s.01')]
# first word : timid
# second word ferocious
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# [Synset('ferocious.s.01')]
# first word : dog
# second word ferocious
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# [Synset('ferocious.s.01')]
# first word : quick
# second word ferocious
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('ferocious.s.01')]
# first word : jumps
# second word ferocious
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('ferocious.s.01')]
# first word : lazy
# second word attitude
# [Synset('lazy.s.01'), Synset('faineant.s.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : fox.Its
# second word attitude
# []
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : is
# second word attitude
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : calm
# second word attitude
# [Synset('composure.n.01'), Synset('calm_air.n.01'), Synset('calm.v.01'), Synset('steady.v.01'), Synset('calm.v.03'), Synset('sedate.v.01'), Synset('calm.s.01'), Synset('calm.a.02')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : A
# second word attitude
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : nature
# second word attitude
# [Synset('nature.n.01'), Synset('nature.n.02'), Synset('nature.n.03'), Synset('nature.n.04'), Synset('nature.n.05')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : over
# second word attitude
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : the
# second word attitude
# []
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : very
# second word attitude
# [Synset('very.s.01'), Synset('identical.s.02'), Synset('very.r.01'), Synset('very.r.02')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : brown
# second word attitude
# [Synset('brown.n.01'), Synset('brown.n.02'), Synset('brown.n.03'), Synset('brown_university.n.01'), Synset('brown.v.01'), Synset('embrown.v.02'), Synset('brown.s.01'), Synset('brown.s.02')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : in
# second word attitude
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : and
# second word attitude
# []
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : .
# second word attitude
# []
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : composure
# second word attitude
# [Synset('composure.n.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : timid
# second word attitude
# [Synset('timid.n.01'), Synset('timid.a.01'), Synset('diffident.a.02'), Synset('faint.s.06')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : dog
# second word attitude
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : quick
# second word attitude
# [Synset('quick.n.01'), Synset('quick.s.01'), Synset('flying.s.02'), Synset('agile.s.01'), Synset('quick.s.04'), Synset('immediate.s.05'), Synset('quick.s.06'), Synset('promptly.r.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# first word : jumps
# second word attitude
# [Synset('jump.n.01'), Synset('leap.n.02'), Synset('jump.n.03'), Synset('startle.n.01'), Synset('jump.n.05'), Synset('jump.n.06'), Synset('jump.v.01'), Synset('startle.v.02'), Synset('jump.v.03'), Synset('jump.v.04'), Synset('leap_out.v.01'), Synset('jump.v.06'), Synset('rise.v.11'), Synset('jump.v.08'), Synset('derail.v.02'), Synset('chute.v.01'), Synset('jump.v.11'), Synset('jumpstart.v.01'), Synset('jump.v.13'), Synset('leap.v.02'), Synset('alternate.v.01')]
# [Synset('attitude.n.01'), Synset('position.n.04'), Synset('attitude.n.03'), Synset('attitude.n.04')]
# Word Order Similarity is: 0.32135890469923556
# Similarity between the sentences between the 2 file is :
#
# 0.5538874669795613
# Want to try once again? if yes press 1 or else 0
